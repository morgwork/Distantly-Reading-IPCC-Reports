# %% [markdown]
# <a href="https://colab.research.google.com/github/morgwork/Distantly-Reading-IPCC-Reports/blob/main/IPCCM1_(4_16).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **This codebook cleans and visualizes prominent terms from the first IPCC "Mitigations" report published in 1990. The PDF of the report (a permanent link available [here](https://https://archive.ipcc.ch/publications_and_data/publications_ipcc_first_assessment_1990_wg3.shtml)) is 332 pages and therefore one of the smaller reports. I converted the PDF into a text file with the use of ABBY Fine Reader 14.**

# %% [markdown]
# ## Cleaning
# In this section, I clean the files for analysis.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords

# %%
import string

all_punctuation = string.punctuation

print(f"All punctuation: {all_punctuation}")
# Out:
# All punctuation: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Remove stopwords function.

def remove_Stopwords(text):
    stop_words = set(stopwords.words('english')) 
    words = word_tokenize( text.lower() ) 
    sentence = [w for w in words if not w in stop_words]
    return " ".join(sentence)

# Lemmatize function.    
def lemmatize_text(text):
    wordlist=[]
    lemmatizer = WordNetLemmatizer() 
    sentences=sent_tokenize(text)
    for sentence in sentences:
        words=word_tokenize(sentence)
        for word in words:
            wordlist.append(lemmatizer.lemmatize(word))
    return ' '.join(wordlist) 

# Cleaning text function.
def clean_text(text): 
    delete_dict = {sp_character: '' for sp_character in string.punctuation} 
    delete_dict[' '] = ' ' 
    table = str.maketrans(delete_dict)
    text1 = text.translate(table)
    textArr= text1.split()
    text2 = ' '.join([w for w in textArr]) 
    
    return text2.lower()

# %%
with open("/content/IPCC1M.txt", "r", encoding='utf-8') as text:
    IPCCM1= text.read()

# %%
MC1= IPCCM1.lower() # remove casing
MC2=MC1
print(MC2[:1000])
# Out:
# ﻿climate change
# 7
# the ipcc
# world meteorological organization/united nations
# environment program
# intergovernmental panel on climate change
# 				>
#
#
#
#
# climate change
# the ipcc response strategies
# climate c ii a n g e
# the ipcc response strategies
# world meteorological organization/united nations environment program
# intergovernmental panel
# on climate change
# note to the reader
# the report of the response strategies working group (rswg) was compiled through an unprecedented international cooperative effort to deal with the many climate change response strategies. the chairs of the four rswg subgroups and the coordinators of the five rswg topic areas took the responsibility for completing their individual reports. along with their respective governments, they contributed generously of their time and resources to that end.
# it was not possible or intended to review each subgroup report and topic paper in plenary session. the rswg report thus constitutes a series of independently prepared underl

# %%
for p in all_punctuation:

  MC3=MC2.replace(p,'')

# %%
MC4=remove_Stopwords(MC3)

# %%
MC5=lemmatize_text(MC4)

# %%
MC6=clean_text(MC5)

# %%
print(MC6[:2000])
# Out:
# ﻿climate change 7 ipcc world meteorological organizationunited nation environment program intergovernmental panel climate change climate change ipcc response strategy climate c ii n g e ipcc response strategy world meteorological organizationunited nation environment program intergovernmental panel climate change note reader report response strategy working group rswg compiled unprecedented international cooperative effort deal many climate change response strategy chair four rswg subgroup coordinator five rswg topic area took responsibility completing individual report along respective government contributed generously time resource end possible intended review subgroup report topic paper plenary session rswg report thus constitutes series independently prepared underlying document attempt analyze thoroughly possible issue addressed subgroup topic area synthesis concept underlying report rswg policymakers summary consensus reached rswg ’ third plenary session geneva june 9 1990 —f m b intergovernmental panel climate change ipcc jointly established u 1988 prof b bolin chairman panel panel ’ charge ass scientific information related various component climate change issue emission major greenhouse gas modification earth ’ radiation balance resulting therefrom needed enable environmental socioeconomic consequence climate change evaluated b formulate realistic response strategy management climate change issue panel began task establishing working goups ii iii respectively ass available scientific information climate change b ass environmental socioeconomic impact climate change c formulate response strategy panel also established special committee participation developing country promote quickly possible full participation developing country activity panel completed first assessment report far far consists • overview • policymakers summary ipcc working group special committee • report ipcc working group overview policymakers summary found single volume report working gr

# %% [markdown]
# ## Analysis
# In this section, I will analyze the cleaned files with some basic word counts to highlight significant terms. I will also create a few WordCloud visualizations for each report, one with all collocates true and two or three that remove disproportionately represented terms and bigrams.

# %%
IPCCM1_words= MC3.split()
print('Number of words in IPCCM1:',len(IPCCM1_words))
# Out:
# Number of words in IPCCM1: 126409

# %%
occurrences = MC6.count("work")
print("Number of times the word \'work\' appears:", occurrences)
# Out:
# Number of times the word 'work' appears: 433

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stopword = stopwords.words("english")

word_tokens = nltk.word_tokenize(MC6)
MC7= [word for word in word_tokens if word not in stopword]

print(MC7)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['\ufeffclimate', 'change', '7', 'ipcc', 'world', 'meteorological', 'organizationunited', 'nation', 'environment', 'program', 'intergovernmental', 'panel', 'climate', 'change', 'climate', 'change', 'ipcc', 'response', 'strategy', 'climate', 'c', 'ii', 'n', 'g', 'e', 'ipcc', 'response', 'strategy', 'world', 'meteorological', 'organizationunited', 'nation', 'environment', 'program', 'intergovernmental', 'panel', 'climate', 'change', 'note', 'reader', 'report', 'response', 'strategy', 'working', 'group', 'rswg', 'compiled', 'unprecedented', 'international', 'cooperative', 'effort', 'deal', 'many', 'climate', 'change', 'response', 'strategy', 'chair', 'four', 'rswg', 'subgroup', 'coordinator', 'five', 'rswg', 'topic', 'area', 'took', 'responsibility', 'completing', 'individual', 'report', 'along', 'respective', 'government', 'contributed', 'generously', 'time', 'resource', 'end', 'possible', 'intended', 'review', 'subgroup', 'report', 'topic', 'paper', 'plenary', 'session', 'rswg', 'report', 'thus', 'constitutes', 'series', 'independently', 'prepared', 'underlying', 'document', 'attempt', 'analyze', 'thoroughly', 'possible', 'issue', 'addressed', 'subgroup', 'topic', 'area', 'synthesis', 'concept', 'underlying', 'report', 'rswg', 'policymakers', 'summary', 'consensus', 'reached', 'rswg', '’', 'third', 'plenary', 'session', 'geneva', 'june', '9', '1990', '—f', 'b', 'intergovernmental', 'panel', 'climate', 'change', 'ipcc', 'jointly', 'established', 'u', '1988', 'prof', 'b', 'bolin', 'chairman', 'panel', 'panel', '’', 'charge', 'ass', 'scientific', 'information', 'related', 'various', 'component', 'climate', 'change', 'issue', 'emission', 'major', 'greenhouse', 'gas', 'modification', 'earth', '’', 'radiation', 'balance', 'resulting', 'therefrom', 'needed', 'enable', 'environmental', 'socioeconomic', 'consequence', 'climate', 'change', 'evaluated', 'b', 'formulate', 'realistic', 'response', 'strategy', 'management', 'climate', 'change', 'issue', 'panel', 'began', 'task', 'establishing', 'working', 'goups', 'ii', 'iii', 'respectively', 'ass', 'available', 'scientific', 'information', 'climate', 'change', 'b', 'ass', 'environmental', 'socioeconomic', 'impact', 'climate', 'change', 'c', 'formulate', 'response', 'strategy', 'panel', 'also', 'established', 'special', 'committee', 'participation', 'developing', 'country', 'promote', 'quickly', 'possible', 'full', 'participation', 'developing', 'country', 'activity', 'panel', 'completed', 'first', 'assessment', 'report', 'far', 'far', 'consists', '•', 
), ('per', 185), ('national', 179), ('future', 178), ('sector', 178), ('year', 178), ('methane', 176), ('natural', 173), ('research', 171), ('production', 166), ('include', 166), ('rise', 162), ('tropical', 161), ('efficiency', 160), ('possible', 152), ('population', 151), ('practice', 150), ('million', 148), ('total', 148), ('world', 146), ('estimate', 145), ('biomass', 145), ('fuel', 144), ('mechanism', 142), ('deforestation', 142), ('existing', 142), ('human', 141), ('issue', 140), ('transfer', 140), ('high', 140), ('reduction', 137), ('action', 136), ('nation', 134), ('1', 134), ('social', 133), ('including', 131), ('many', 129), ('one', 128), ('convention', 127), ('case', 127), ('supply', 126), ('result', 125), ('factor', 125)]

# %%
import pandas as pd

df = pd.DataFrame(list(freq.most_common(20)))
df.columns =['word', 'count']
df.plot(kind='bar');

# %%
print(df)
# Out:
#            word  count
# 0      emission   1144
# 1        change    875
# 2       climate    767
# 3       country    564
# 4        forest    528
# 5           gas    487
# 6           may    485
# 7           use    477
# 8        energy    463
# 9      response    455
# 10     resource    429
# 11   greenhouse    427
# 12     economic    407
# 13        could    393
# 14      measure    391
# 15        level    390
# 16  development    389
# 17       option    383
# 18         area    375
# 19     strategy    367

# %%
MC9=print(freq.most_common(50))
# Out:
# [('emission', 1144), ('change', 875), ('climate', 767), ('country', 564), ('forest', 528), ('gas', 487), ('may', 485), ('use', 477), ('energy', 463), ('response', 455), ('resource', 429), ('greenhouse', 427), ('economic', 407), ('could', 393), ('measure', 391), ('level', 390), ('development', 389), ('option', 383), ('area', 375), ('strategy', 367), ('technology', 351), ('scenario', 350), ('management', 339), ('would', 338), ('developing', 321), ('policy', 316), ('coastal', 298), ('percent', 298), ('land', 298), ('global', 290), ('impact', 289), ('group', 280), ('carbon', 280), ('need', 275), ('cost', 275), ('international', 264), ('also', 262), ('water', 259), ('system', 254), ('increase', 242), ('report', 229), ('growth', 218), ('working', 216), ('co2', 214), ('source', 212), ('information', 208), ('agricultural', 207), ('ipcc', 203), ('effect', 200), ('activity', 199)]

# %%
MC9=','.join(MC8)
print(MC9)
# Out:
# change,7,ipcc,world,meteorological,organizationunited,nation,environment,program,intergovernmental,panel,climate,change,climate,change,ipcc,response,strategy,climate,c,ii,n,g,e,ipcc,response,strategy,world,meteorological,organizationunited,nation,environment,program,intergovernmental,panel,climate,change,note,reader,report,response,strategy,working,group,rswg,compiled,unprecedented,international,cooperative,effort,deal,many,climate,change,response,strategy,chair,four,rswg,subgroup,coordinator,five,rswg,topic,area,took,responsibility,completing,individual,report,along,respective,government,contributed,generously,time,resource,end,possible,intended,review,subgroup,report,topic,paper,plenary,session,rswg,report,thus,constitutes,series,independently,prepared,underlying,document,attempt,analyze,thoroughly,possible,issue,addressed,subgroup,topic,area,synthesis,concept,underlying,report,rswg,policymakers,summary,consensus,reached,rswg,third,plenary,session,geneva,june,9,1990,b,intergovernmental,panel,climate,change,ipcc,jointly,established,u,1988,prof,b,bolin,chairman,panel,panel,charge,ass,scientific,information,related,various,component,climate,change,issue,emission,major,greenhouse,gas,modification,earth,radiation,balance,resulting,therefrom,needed,enable,environmental,socioeconomic,consequence,climate,change,evaluated,b,formulate,realistic,response,strategy,management,climate,change,issue,panel,began,task,establishing,working,goups,ii,iii,respectively,ass,available,scientific,information,climate,change,b,ass,environmental,socioeconomic,impact,climate,change,c,formulate,response,strategy,panel,also,established,special,committee,participation,developing,country,promote,quickly,possible,full,participation,developing,country,activity,panel,completed,first,assessment,report,far,far,consists,overview,policymakers,summary,ipcc,working,group,special,committee,report,ipcc,working,group,overview,policymakers,summary,found,single,volume,report,working,group,published,individually,present,volume,based,upon,finding,working,group,iii,order,appreciate,linkage,among,various,aspect,climate,change,issue,recommended,read,context,full,ipcc,first,assessment,report,chairman,working,group,iii,dr,f,bernthal,secretariat,succeeded,beyond,measure,mobilizing,cooperation,enthusiasm,literally,hundred,expert,world,produced,volume,remarkable,depth,breadth,policymakers,summary,model,writing,aiming,explaining,complex,issue,nonspecialist,take,opportunity,congratulate,thank,dr,bernthal,job,well,done,g,p,obasi,secretarygeneral,wmo,k,tqlba,executive,director,unep,officer,working,group,iii,chairman,f,bernthal,usa,cochairs,e,dowdeswcll,canada,j,luo,china,attard,malta,p,vcllinga,netherlands,r,karimanzira,zimbabwe,lead,contributor,rswg,subgroup,cochairs,energy,industry,k,yokobori,japan,shaoxiong,xie,china,agriculture,forestry,human,activity,kupfer,germany,fed,rep,r,karimanzira,zimbabwe,coastal,zone,management,j,gilbert,new,zealand,p,vellinga,netherlands,resource,use,management,r,pentland,canada,j,theys,france,abrol,india,task,emission,scenario,coordinator,tirpak,usa,p,vellinga,netherlands,task,b,implementation,mechanism,coordinator,public,education,information,g,evans,usa,jibin,luo,china,technology,development,transfer,k,madhava,sarma,india,k,haraguchi,j,apan,economic,market,measure,j,tilley,australia,j,gilbert,new,zealand,financial,measure,j,oppcncau,france,p,vellinga,netherlands,ibrahim,egypt,legal,institutional,mechanism,r,rochon,canada,attard,malta,r,beetham,uk,acknowledgment,work,response,strategy,working,group,organized,coordinated,network,officer,world,take,opportunity,thank,rswg,vicechairs,dedication,ensuring,working,group,iii,able,fulfill,mission,assigned,special,credit,go,cochairs,four,rswg,subgroup,coordinator,task,emission,scenario,task,b,implementation,measure,guided,effort,hundred,expert,score,country,around,world,contributed,preparation,specific,section,report,addition,would,like,express,gratitude,staff,office,global,change,us,department,state,daniel,reifs ...

# %%
import pandas as pd
df=pd.DataFrame({'author': ['IPCC'], 'report': MC9}) 
df
# Out:
#   author                                             report
# 0   IPCC  change,7,ipcc,world,meteorological,organizatio...

# %%
import numpy as np
import matplotlib.pyplot as plt
import string
import seaborn as sns
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(background_color=(246,235,189),max_words=25, width=800, height=400,random_state=30,stopwords=["emission," "emissions"]).generate(' '.join(df['report'].tolist()))
plt.figure( figsize=(20,10))
plt.imshow(wordcloud); # removing climate change

# %%
wordcloud = WordCloud(background_color=(246,235,189),max_words=50, width=800, height=400,random_state=30,stopwords=[]).generate(' '.join(df['report'].tolist()))
plt.figure( figsize=(20,10))
plt.imshow(wordcloud);

# can remove words with the stopwords function in first line. because it reads for bigrams, have to remove individual terms 

# add ",collocations=False" before generate function in first line to stop bigrams and focus on individual terms; must be in parentheses

# change max_words number to increase or limit terms

# %%
wordcloud_ab = WordCloud(background_color="white",max_words=20, width=800, height=400,stopwords=["climate", "change"], collocations=False).generate(' '.join(df['report'].tolist()))
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud_ab); # removing bigrams and select stopwords
